# %% [markdown]
# # Intro To Data Science

# %% [markdown]
# # Assignment No:1

# %% [markdown]
# # Name:Eisha Qaiser

# %% [markdown]
# # Roll No:211980054

# %% [markdown]
# # ..................................................................................

# %% [markdown]
#                         **Task No : 1**

# %% [markdown]
# # Import pandas Library

# %%
import pandas as pd
df = pd.read_csv("Dummy_Sales_Data_v1.csv")

# %% [markdown]
# # Print Data Frame

# %%
df
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 0     2951110000999929511        92             238  Not Delivered
# 1     2181910000999921819        61             136  Not Delivered
# 2     3239110000999932391        67             235  Not Delivered
# 3     1112610000999911126        33             133    Not Shipped
# 4     1548310000999915483        13             189  Not Delivered
# ...                   ...       ...             ...            ...
# 9994  2301610000999923016        75             201  Not Delivered
# 9995  1847410000999918474        37             135        Shipped
# 9996  2385710000999923857        81             207      Delivered
# 9997  2281610000999922816        18             117        Shipped
# 9998  1468010000999914680        53             229      Delivered
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 0     2021-08-08       Healthcare         Pablo                  21
# ...

# %% [markdown]
# # Data Frame .Head() Funtion

# %%
#df.head(): Function which returns the first 5 rows of the dataset.
#you can access the First Rows according to you Need.
#df.head(10):It returns the first 10 Rows of your data Set
df.head()
# Out:
#                OrderID  Quantity  UnitPrice(USD)         Status   OrderDate  \
# 0  2951110000999929511        92             238  Not Delivered  2021-08-08
# 1  2181910000999921819        61             136  Not Delivered  2021-10-03
# 2  3239110000999932391        67             235  Not Delivered  2021-09-27
# 3  1112610000999911126        33             133    Not Shipped  2021-07-30
# 4  1548310000999915483        13             189  Not Delivered  2021-08-15
#
#   Product_Category Sales_Manager  Shipping_Cost(USD)  Delivery_Time(Days)  \
# 0       Healthcare         Pablo                  21                 25.0
# 1           Office         Pablo                  34                 14.0
# 2           Office       Kristen                  25                 11.0
# 3          Fashion         Abdul                  34                 24.0
# 4          Fashion        Stella                  24                 19.0
#
#   Shipping_Address Product_Code  OrderCode
# ...

# %% [markdown]
# # Data Frame .Tail() Function

# %%
#This function helps you to get the last few rows of the dataset. By default,
#it returns the last5 rows  of df. you can simply mention the desired number of rows
#df.tail(10) it returns the last 10 rows of your data set
df.tail()
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 9994  2301610000999923016        75             201  Not Delivered
# 9995  1847410000999918474        37             135        Shipped
# 9996  2385710000999923857        81             207      Delivered
# 9997  2281610000999922816        18             117        Shipped
# 9998  1468010000999914680        53             229      Delivered
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 9994  2021-10-16             Home         Sofia                  20
# 9995  2021-10-03       Healthcare         Maria                  30
# 9996  2021-11-13           Office          Emma                  29
# 9997  2021-12-23          Fashion        Stella                  22
# 9998  2021-07-12    Entertainment       Anthony                  25
#
#       Delivery_Time(Days) Shipping_Address Product_Code  OrderCode
# 9994                 14.0            Kenya        H-555     444885
# ...

# %% [markdown]
# # Data Frame.Sample() Function

# %%
#The sample() method returns a specified number of random rows. 
#The sample() method returns 1 row if a number is not specified.
df.sample(1)
# Out:
#                   OrderID  Quantity  UnitPrice(USD)     Status   OrderDate  \
# 1415  2218010000999922180        39             188  Delivered  2021-10-03
#
#      Product_Category Sales_Manager  Shipping_Cost(USD)  Delivery_Time(Days)  \
# 1415             Home       Kristen                  24                 13.0
#
#      Shipping_Address Product_Code  OrderCode
# 1415            Kenya        H-901     444772

# %% [markdown]
# # Data Frame().info Function

# %%
#This function returns a  information  of the DataFrame.
#This  information aboutcolumn names and their respective data types,missing values.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9999 entries, 0 to 9998
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   OrderID              9999 non-null   int64
#  1   Quantity             9999 non-null   int64
#  2   UnitPrice(USD)       9999 non-null   int64
#  3   Status               9999 non-null   object
#  4   OrderDate            9999 non-null   object
#  5   Product_Category     9963 non-null   object
#  6   Sales_Manager        9999 non-null   object
#  7   Shipping_Cost(USD)   9999 non-null   int64
#  8   Delivery_Time(Days)  9948 non-null   float64
#  9   Shipping_Address     9999 non-null   object
#  10  Product_Code         9999 non-null   object
#  11  OrderCode            9999 non-null   int64
# dtypes: float64(1), int64(5), object(6)
# memory usage: 937.5+ KB

# %% [markdown]
# # Data Frame.describe() Function

# %%
#This function returns  statistics values about the data. This includes
#minimum,maximum, mean and  standard deviation  of the values in columns.
df.describe()
# Out:
#             OrderID     Quantity  UnitPrice(USD)  Shipping_Cost(USD)  \
# count  9.999000e+03  9999.000000     9999.000000         9999.000000
# mean   3.020951e+18    50.739874      175.620662           27.571857
# std    1.167549e+18    29.005532       43.527995            4.610452
# min    1.010010e+18     1.000000      100.000000           20.000000
# 25%    2.010410e+18    26.000000      138.000000           24.000000
# 50%    3.002410e+18    51.000000      176.000000           28.000000
# 75%    4.024510e+18    76.000000      213.000000           32.000000
# max    5.049610e+18   100.000000      250.000000           35.000000
#
#        Delivery_Time(Days)      OrderCode
# count          9948.000000    9999.000000
# mean             17.518396  444682.917392
# std               4.609531     525.343171
# min              10.000000  443880.000000
# 25%              14.000000  444222.000000
# 50%              18.000000  444772.000000
# 75%              22.000000  445113.000000
# ...

# %% [markdown]
# # Data Frame .Query() Function

# %%
#This function is used to query the DataFrame based on an expression. An expression
#can be as simple as a single condition and as complex as a combination of multiple conditions.
df.query("Quantity < 100")
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 0     2951110000999929511        92             238  Not Delivered
# 1     2181910000999921819        61             136  Not Delivered
# 2     3239110000999932391        67             235  Not Delivered
# 3     1112610000999911126        33             133    Not Shipped
# 4     1548310000999915483        13             189  Not Delivered
# ...                   ...       ...             ...            ...
# 9994  2301610000999923016        75             201  Not Delivered
# 9995  1847410000999918474        37             135        Shipped
# 9996  2385710000999923857        81             207      Delivered
# 9997  2281610000999922816        18             117        Shipped
# 9998  1468010000999914680        53             229      Delivered
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 0     2021-08-08       Healthcare         Pablo                  21
# ...

# %% [markdown]
# # Data Frame.Loc() Function

# %%
#This function  returns the group of rows and columnsidentified by their 
#labels or names.
df.loc[50,'Status']
# Out:
# 'Not Shipped'

# %% [markdown]
# # Data Frame.Unique() Function

# %%
df["Product_Code"].unique()
# Out:
# array(['HC-188', 'O-555', 'O-188', 'F-555', 'ENT-188', 'HC-555', 'F-203',
#        'F-901', 'H-555', 'ENT-901', 'H-188', 'H-901', 'H-203', 'HC-203',
#        'ENT-101', 'HC-901', 'O-630', 'ENT-630', 'HC-630', 'O-901',
#        'H-101', 'HC-101', 'F-630', 'O-101', 'H-630', 'ENT-203', 'O-203',
#        'ENT-555', 'F-188', 'F-101'], dtype=object)

# %% [markdown]
# # Data Frame.Nunique() Function

# %%
#The nunique() method returns the number of unique values for each column.
#By specifying the column axis ( axis='columns' ) For columns.
df.nunique()
# Out:
# OrderID                8842
# Quantity                100
# UnitPrice(USD)          151
# Status                    4
# OrderDate               108
# Product_Category          5
# Sales_Manager            10
# Shipping_Cost(USD)       16
# Delivery_Time(Days)      16
# Shipping_Address          8
# Product_Code             30
# OrderCode               108
# dtype: int64

# %% [markdown]
# # Data Frame.is Null() Function

# %%
#The isnull() method returns a DataFrame object where all the values are 
#replaced with a Boolean value True for NULL values, and otherwise False
df.isnull()
# Out:
#       OrderID  Quantity  UnitPrice(USD)  Status  OrderDate  Product_Category  \
# 0       False     False           False   False      False             False
# 1       False     False           False   False      False             False
# 2       False     False           False   False      False             False
# 3       False     False           False   False      False             False
# 4       False     False           False   False      False             False
# ...       ...       ...             ...     ...        ...               ...
# 9994    False     False           False   False      False             False
# 9995    False     False           False   False      False             False
# 9996    False     False           False   False      False             False
# 9997    False     False           False   False      False             False
# 9998    False     False           False   False      False             False
#
# ...

# %% [markdown]
# # Data Frame.Fillna() Function

# %%
#The fillna() method replaces the NULL values with a specified value. 
df.fillna(222)
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 0     2951110000999929511        92             238  Not Delivered
# 1     2181910000999921819        61             136  Not Delivered
# 2     3239110000999932391        67             235  Not Delivered
# 3     1112610000999911126        33             133    Not Shipped
# 4     1548310000999915483        13             189  Not Delivered
# ...                   ...       ...             ...            ...
# 9994  2301610000999923016        75             201  Not Delivered
# 9995  1847410000999918474        37             135        Shipped
# 9996  2385710000999923857        81             207      Delivered
# 9997  2281610000999922816        18             117        Shipped
# 9998  1468010000999914680        53             229      Delivered
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 0     2021-08-08       Healthcare         Pablo                  21
# ...

# %% [markdown]
# # Data Frame.Sort_Values() Function

# %%
#In order to sort the data frame in pandas, function sort_values() is used.
df.sort_values(by='Quantity')
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 3367  4733210000999947332         1             213    Not Shipped
# 5952  2228310000999922283         1             203  Not Delivered
# 5569  3732610000999937326         1             165        Shipped
# 9516  2719510000999927195         1             247  Not Delivered
# 3429  3276610000999932766         1             157    Not Shipped
# ...                   ...       ...             ...            ...
# 7820  2478510000999924785       100             187      Delivered
# 2739  1262510000999912625       100             101        Shipped
# 551   3442310000999934423       100             218  Not Delivered
# 2719  2829410000999928294       100             117    Not Shipped
# 503   2085610000999920856       100             108  Not Delivered
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 3367  2021-07-04    Entertainment         Maria                  26
# ...

# %% [markdown]
# # Data Frame.value_counts() Function

# %%
#Return a Series containing counts of unique values.
#The resulting object will be in descending order.
df["Product_Category"].value_counts()
# Out:
# Home             2060
# Office           2011
# Fashion          1971
# Entertainment    1968
# Healthcare       1953
# Name: Product_Category, dtype: int64

# %% [markdown]
# # Data Frame.nlargest() Function

# %%
#The nlargest() method returns a specified number of rows.
#starting at the top after sorting the DataFrame by the highest value for a specified column.
df.nlargest(5 , "Quantity")
# Out:
#                  OrderID  Quantity  UnitPrice(USD)         Status   OrderDate  \
# 25   3063710000999930637       100             173  Not Delivered  2021-12-22
# 54   4861510000999948615       100             237        Shipped  2021-10-03
# 185  2768610000999927686       100             241    Not Shipped  2021-12-18
# 417  1015510000999910155       100             154  Not Delivered  2021-07-31
# 503  2085610000999920856       100             108  Not Delivered  2021-12-24
#
#     Product_Category Sales_Manager  Shipping_Cost(USD)  Delivery_Time(Days)  \
# 25            Office         Jacob                  21                 23.0
# 54            Office          John                  25                 13.0
# 185           Office       Kristen                  29                 12.0
# 417    Entertainment       Kristen                  33                 10.0
# 503       Healthcare       Kristen                  20                 19.0
#
# ...

# %% [markdown]
# # Data Frame.nsmallest() Function

# %%
#The nsmallest method is used to return the first n rows in ascending order with the smallest values in columns.
df.nsmallest(5 , "Quantity")
# Out:
#                  OrderID  Quantity  UnitPrice(USD)       Status   OrderDate  \
# 27   4956110000999949561         1             154  Not Shipped  2021-10-04
# 29   3348510000999933485         1             212    Delivered  2021-12-18
# 56   3594610000999935946         1             196    Delivered  2021-11-11
# 326  2549410000999925494         1             126    Delivered  2021-10-10
# 338  1074510000999910745         1             249      Shipped  2021-08-14
#
#     Product_Category Sales_Manager  Shipping_Cost(USD)  Delivery_Time(Days)  \
# 27           Fashion         Pablo                  26                 23.0
# 29              Home         Sofia                  31                 24.0
# 56        Healthcare          John                  35                 21.0
# 326          Fashion       Kristen                  24                 12.0
# 338             Home         Sofia                  27                 18.0
#
#     Shipping_Address Product_Code  OrderCode
# ...

# %% [markdown]
# # Data Frame.copy() Function

# %%
#The copy() method returns a copy of the DataFrame.
#By default, the copy is a "deep copy" meaning that any changes made in the original DataFrame will NOT be reflected in the copy.
df.copy()
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 0     2951110000999929511        92             238  Not Delivered
# 1     2181910000999921819        61             136  Not Delivered
# 2     3239110000999932391        67             235  Not Delivered
# 3     1112610000999911126        33             133    Not Shipped
# 4     1548310000999915483        13             189  Not Delivered
# ...                   ...       ...             ...            ...
# 9994  2301610000999923016        75             201  Not Delivered
# 9995  1847410000999918474        37             135        Shipped
# 9996  2385710000999923857        81             207      Delivered
# 9997  2281610000999922816        18             117        Shipped
# 9998  1468010000999914680        53             229      Delivered
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 0     2021-08-08       Healthcare         Pablo                  21
# ...

# %% [markdown]
# # Data Frame.rename() Function

# %%
#The rename() function is used to alter axes labels.
df.rename(columns= {"Quantity" : "Product Quantity" , "Sales_Manager" : "Manager"})
# Out:
#                   OrderID  Product Quantity  UnitPrice(USD)         Status  \
# 0     2951110000999929511                92             238  Not Delivered
# 1     2181910000999921819                61             136  Not Delivered
# 2     3239110000999932391                67             235  Not Delivered
# 3     1112610000999911126                33             133    Not Shipped
# 4     1548310000999915483                13             189  Not Delivered
# ...                   ...               ...             ...            ...
# 9994  2301610000999923016                75             201  Not Delivered
# 9995  1847410000999918474                37             135        Shipped
# 9996  2385710000999923857                81             207      Delivered
# 9997  2281610000999922816                18             117        Shipped
# 9998  1468010000999914680                53             229      Delivered
#
#        OrderDate Product_Category  Manager  Shipping_Cost(USD)  \
# ...

# %% [markdown]
# # Data Frame.where()

# %%
#DataFrame. where() function is similar to if else that is used to check the 
#one or multiple conditions of an expression in DataFrame and replace with another value when the condition becomes False
condition = df["Quantity"] > 20
result = df.where(condition , other = 1 )
result
# Out:
#                   OrderID  Quantity  UnitPrice(USD)         Status  \
# 0     2951110000999929511        92             238  Not Delivered
# 1     2181910000999921819        61             136  Not Delivered
# 2     3239110000999932391        67             235  Not Delivered
# 3     1112610000999911126        33             133    Not Shipped
# 4                       1         1               1              1
# ...                   ...       ...             ...            ...
# 9994  2301610000999923016        75             201  Not Delivered
# 9995  1847410000999918474        37             135        Shipped
# 9996  2385710000999923857        81             207      Delivered
# 9997                    1         1               1              1
# 9998  1468010000999914680        53             229      Delivered
#
#        OrderDate Product_Category Sales_Manager  Shipping_Cost(USD)  \
# 0     2021-08-08       Healthcare         Pablo                  21
# ...

# %% [markdown]
# #  Data Frame.drop() Function

# %%
#The drop() method removes the specified row or column.
#By specifying the column axis ( axis='columns' ), the drop() method removes the specified column
df.drop("Quantity", axis='columns')
# Out:
#                   OrderID  UnitPrice(USD)         Status   OrderDate  \
# 0     2951110000999929511             238  Not Delivered  2021-08-08
# 1     2181910000999921819             136  Not Delivered  2021-10-03
# 2     3239110000999932391             235  Not Delivered  2021-09-27
# 3     1112610000999911126             133    Not Shipped  2021-07-30
# 4     1548310000999915483             189  Not Delivered  2021-08-15
# ...                   ...             ...            ...         ...
# 9994  2301610000999923016             201  Not Delivered  2021-10-16
# 9995  1847410000999918474             135        Shipped  2021-10-03
# 9996  2385710000999923857             207      Delivered  2021-11-13
# 9997  2281610000999922816             117        Shipped  2021-12-23
# 9998  1468010000999914680             229      Delivered  2021-07-12
#
#      Product_Category Sales_Manager  Shipping_Cost(USD)  Delivery_Time(Days)  \
# ...

# %% [markdown]
# # Data Frame.corr() Function

# %%
#corr() method is to find the pairwise correlation of all the columns in the DataFrame. If any null value is present,
#Sit will automatically be excluded.
result = df.corr()
result
# Out:
#                       OrderID  Quantity  UnitPrice(USD)  Shipping_Cost(USD)  \
# OrderID              1.000000  0.008028        0.000866           -0.002899
# Quantity             0.008028  1.000000       -0.007948           -0.008935
# UnitPrice(USD)       0.000866 -0.007948        1.000000           -0.002698
# Shipping_Cost(USD)  -0.002899 -0.008935       -0.002698            1.000000
# Delivery_Time(Days) -0.017483 -0.003023       -0.013938           -0.004026
# OrderCode            0.005441 -0.002827        0.015882            0.008126
#
#                      Delivery_Time(Days)  OrderCode
# OrderID                        -0.017483   0.005441
# Quantity                       -0.003023  -0.002827
# UnitPrice(USD)                 -0.013938   0.015882
# Shipping_Cost(USD)             -0.004026   0.008126
# Delivery_Time(Days)             1.000000   0.008851
# OrderCode                       0.008851   1.000000

# %% [markdown]
# # ..........................THE END................................
